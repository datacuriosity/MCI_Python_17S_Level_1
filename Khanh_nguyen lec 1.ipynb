# %%
print:'Hello world'

# %%
print ('Hello world')
# Out:
# Hello world

# %%
 a = 5
 b = 7
print (a+b)
# Out:
# 12

# %%
a = 5
for a<9
print (a)
a = a+1
# Out:
#   File "<ipython-input-13-3548caa9b4f7>", line 2
#     for a<9
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# ######### ABCD 4

# %% [markdown]
# **BOLD**

# %% [markdown]
# - list 1
# - list 2
# - list 3

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1+1

# %% [markdown]
# ![(https://www.w3schools.com/python/python_for_loops.asp)]

# %%
![(https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM)]
# Out:
# '[' is not recognized as an internal or external command,
# operable program or batch file.
# 'sxsrf' is not recognized as an internal or external command,
# operable program or batch file.
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
# 'tbm' is not recognized as an internal or external command,
# operable program or batch file.
# 'sa' is not recognized as an internal or external command,
# operable program or batch file.
# 'ved' is not recognized as an internal or external command,
# operable program or batch file.
# 'biw' is not recognized as an internal or external command,
# operable program or batch file.
# 'bih' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![(https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM)]

# %%
![](https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.
# 'sxsrf' is not recognized as an internal or external command,
# operable program or batch file.
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
# 'tbm' is not recognized as an internal or external command,
# operable program or batch file.
# 'sa' is not recognized as an internal or external command,
# operable program or batch file.
# 'ved' is not recognized as an internal or external command,
# operable program or batch file.
# 'biw' is not recognized as an internal or external command,
# operable program or batch file.
# 'bih' is not recognized as an internal or external command,
# operable program or batch file.

# %%
[https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM]
# Out:
#   File "<ipython-input-19-90b83a750911>", line 1
#     [https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM]
#           ^
# SyntaxError: invalid syntax

# %%
![](https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.
# 'sxsrf' is not recognized as an internal or external command,
# operable program or batch file.
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
# 'tbm' is not recognized as an internal or external command,
# operable program or batch file.
# 'sa' is not recognized as an internal or external command,
# operable program or batch file.
# 'ved' is not recognized as an internal or external command,
# operable program or batch file.
# 'biw' is not recognized as an internal or external command,
# operable program or batch file.
# 'bih' is not recognized as an internal or external command,
# operable program or batch file.

# %%
![]https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM
# Out:
# '[]https://www.google.com/search?q' is not recognized as an internal or external command,
# operable program or batch file.
# 'sxsrf' is not recognized as an internal or external command,
# operable program or batch file.
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
# 'tbm' is not recognized as an internal or external command,
# operable program or batch file.
# 'sa' is not recognized as an internal or external command,
# operable program or batch file.
# 'ved' is not recognized as an internal or external command,
# operable program or batch file.
# 'biw' is not recognized as an internal or external command,
# operable program or batch file.
# 'bih' is not recognized as an internal or external command,
# operable program or batch file.

# %%
![](https://www.google.com/search?q=CFA&sxsrf=ALeKk0149XROiXk6FDuk_ZmnAqXjsMmX-w:1608042341217&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjjtaDEmNDtAhWOd94KHdjzCQMQ_AUoAXoECAYQAw&biw=1696&bih=798#imgrc=azuKz_Npjz-coM)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.
# 'sxsrf' is not recognized as an internal or external command,
# operable program or batch file.
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
# 'tbm' is not recognized as an internal or external command,
# operable program or batch file.
# 'sa' is not recognized as an internal or external command,
# operable program or batch file.
# 'ved' is not recognized as an internal or external command,
# operable program or batch file.
# 'biw' is not recognized as an internal or external command,
# operable program or batch file.
# 'bih' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![](https://cdn.vietnambiz.vn/2019/12/11/gift-for-you-1576057245352703480589.png)

# %% [markdown]
# ![](C:\Users\USER\Desktop\Pics\2.jpg)

# %% [markdown]
# ![2.jpg](attachment:828a5735-169d-4914-a4b8-64c31234f93b.jpg)

# %% [raw]
# ##Operation

# %%
10+1
# Out:
# 11

# %%
9*29
# Out:
# 261

# %%
10%3
# Out:
# 1

# %%
10//2
# Out:
# 5

# %%
10//6
# Out:
# 1

# %%
10^2
# Out:
# 8

# %%
10**2
# Out:
# 100

# %%
10**(1/3)
# Out:
# 2.154434690031884

# %%
9**(1/2)
# Out:
# 3.0

# %%
round(10/3)
# Out:
# 3

# %%
round(11/3)
# Out:
# 4

# %%
abs(-9)
# Out:
# 9

# %% [markdown]
# ## Data structure

# %% [markdown]
# ### 2.1 Data type

# %% [markdown]
# ### Programing = Data structure + Algorithm
#  - Data type

# %% [markdown]
# - Numeric:int, float, complex
# - Booleans
# - None type
