# %%
import pandas as pd

# %% [markdown]
# ## Data structure in pandas:
# - Series: series chỉ duy nhất 1 cột
# - DataFrame
# - Index

# %%
series = pd.Series(['Name', 'Khoi','Minh','Huynh'])
series
# Out:
# 0     Name
# 1     Khoi
# 2     Minh
# 3    Huynh
# dtype: object

# %%
series = pd.Series(['Name', 'Trang','Diệu','Huynh'], index = ['a','T','D','F'], name = 'AGE') # name: tên của series
series
# Out:
# a     Name
# T    Trang
# D     Diệu
# F    Huynh
# Name: AGE, dtype: object

# %%
df = pd.DataFrame({'Name': ['AA','BB', 'CC', 'DD'],'Age': [20,22,18,29],'Score':[7,8,8,9]})
df
# Out:
#   Name  Age  Score
# 0   AA   20      7
# 1   BB   22      8
# 2   CC   18      8
# 3   DD   29      9

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
apple = yf.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    0.936384    1.004464    0.907924    0.999442    0.862170
# 2000-01-04    0.966518    0.987723    0.903460    0.915179    0.789479
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.801033
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.731713
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.766373
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2000-01-03  535796800
# 2000-01-04  512377600
# 2000-01-05  778321600
# ...

# %%
apple.Close.plot(figsize=(10,6),xlabel = 'Date',ylabel = 'Closing price');

# %% [markdown]
# # 1.Series

# %%
appl_series = apple.Close
appl_series
# Out:
# Date
# 2000-01-03      0.999442
# 2000-01-04      0.915179
# 2000-01-05      0.928571
# 2000-01-06      0.848214
# 2000-01-07      0.888393
#                  ...
# 2020-12-23    130.960007
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# Name: Close, Length: 5283, dtype: float64

# %%
#method 2
appl_series = apple['Close']
appl_series
# Out:
# Date
# 2000-01-03      0.999442
# 2000-01-04      0.915179
# 2000-01-05      0.928571
# 2000-01-06      0.848214
# 2000-01-07      0.888393
#                  ...
# 2020-12-23    130.960007
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# Name: Close, Length: 5283, dtype: float64

# %%
appl_series.index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=5283, freq=None)

# %%
type(appl_series.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
appl_series.index[1].year
# Out:
# 2000

# %%
appl_series.head() # mặc định là 5 dòng đầu tiên
# Out:
# Date
# 2000-01-03    0.999442
# 2000-01-04    0.915179
# 2000-01-05    0.928571
# 2000-01-06    0.848214
# 2000-01-07    0.888393
# Name: Close, dtype: float64

# %%
appl_series.head(7)
# Out:
# Date
# 2000-01-03    0.999442
# 2000-01-04    0.915179
# 2000-01-05    0.928571
# 2000-01-06    0.848214
# 2000-01-07    0.888393
# 2000-01-10    0.872768
# 2000-01-11    0.828125
# Name: Close, dtype: float64

# %%
appl_series.describe()
# Out:
# count    5283.000000
# mean       18.707354
# std        23.779799
# min         0.234286
# 25%         1.356429
# 50%         9.187500
# 75%        27.593750
# max       136.690002
# Name: Close, dtype: float64

# %%
appl_series.mode()
# Out:
# 0    0.267857
# 1    0.348214
# dtype: float64

# %%
appl_series.quantile(0.90)
# Out:
# 47.533998870849615

# %% [markdown]
# [](https://academy.vertabelo.com/static/statistics-101-04-quartiles-3.png)

# %% [markdown]
# ![](https://academy.vertabelo.com/static/statistics-101-04-quartiles-3.png)

# %%
# THÊM HÌNH: 
#MARKDOWN MODE, SYNCTAX: ![](LINK)

# %% [markdown]
# ### 1. SLICING DATA
# - iloc[row_index]
# - loc[row_label]

# %%
appl_series.iloc[2] # dòng thứ 3
# Out:
# 0.9285714030265808

# %%
appl_series.loc['2000-01-05'] # đưa label vào
# Out:
# 0.9285714030265808

# %%
appl_series.iloc[2:5] # Exclusive
# Out:
# Date
# 2000-01-05    0.928571
# 2000-01-06    0.848214
# 2000-01-07    0.888393
# Name: Close, dtype: float64

# %%
appl_series.loc['2000-01-05':'2000-01-16']
# Out:
# Date
# 2000-01-05    0.928571
# 2000-01-06    0.848214
# 2000-01-07    0.888393
# 2000-01-10    0.872768
# 2000-01-11    0.828125
# 2000-01-12    0.778460
# 2000-01-13    0.863839
# 2000-01-14    0.896763
# Name: Close, dtype: float64

# %%
appl_series <1.0
# Out:
# Date
# 2000-01-03     True
# 2000-01-04     True
# 2000-01-05     True
# 2000-01-06     True
# 2000-01-07     True
#               ...
# 2020-12-23    False
# 2020-12-24    False
# 2020-12-28    False
# 2020-12-29    False
# 2020-12-30    False
# Name: Close, Length: 5283, dtype: bool

# %%
appl_series[appl_series <1.0]
# Out:
# Date
# 2000-01-03    0.999442
# 2000-01-04    0.915179
# 2000-01-05    0.928571
# 2000-01-06    0.848214
# 2000-01-07    0.888393
#                 ...
# 2004-11-15    0.986429
# 2004-11-16    0.981071
# 2004-11-17    0.980357
# 2004-11-18    0.989107
# 2004-11-19    0.985179
# Name: Close, Length: 1143, dtype: float64

# %% [markdown]
# apple

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    0.936384    1.004464    0.907924    0.999442    0.862170
# 2000-01-04    0.966518    0.987723    0.903460    0.915179    0.789479
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.801033
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.731713
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.766373
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2000-01-03  535796800
# 2000-01-04  512377600
# 2000-01-05  778321600
# ...

# %%
apple.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5283.000000  5283.000000  5283.000000  5283.000000  5283.000000
# mean     18.700753    18.900474    18.499010    18.707354    17.697313
# std      23.767826    24.053821    23.480229    23.779799    23.585829
# min       0.231964     0.235536     0.227143     0.234286     0.202107
# 25%       1.352143     1.373214     1.337857     1.356429     1.170124
# 50%       9.177857     9.280357     9.089286     9.187500     7.925606
# 75%      27.585000    27.936250    27.298750    27.593750    25.630529
# max     138.050003   138.789993   134.339996   136.690002   136.690002
#
#              Volume
# count  5.283000e+03
# mean   4.451135e+08
# std    3.914047e+08
# min    2.420510e+07
# 25%    1.769182e+08
# 50%    3.325896e+08
# 75%    5.926284e+08
# max    7.421641e+09

# %% [markdown]
# ## SLICING DATAFRAME
# - iloc[row_index,column_index]
# - loc[row_lable,column_label]

# %%
apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.862170  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.789479  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.801033  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.731713  767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.766373  460734400

# %%
apple.loc['2000-01-04','Close']
# Out:
# 0.9151785969734192

# %%
apple.loc['2000-01-04':'2000-01-07','Open':'Close']
# Out:
#                 Open      High       Low     Close
# Date
# 2000-01-04  0.966518  0.987723  0.903460  0.915179
# 2000-01-05  0.926339  0.987165  0.919643  0.928571
# 2000-01-06  0.947545  0.955357  0.848214  0.848214
# 2000-01-07  0.861607  0.901786  0.852679  0.888393

# %% [markdown]
# # MASKING

# %%
apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.862170  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.789479  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.801033  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.731713  767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.766373  460734400

# %%
#method 1
apple[apple.Close<0.9]
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.731713   767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.766373   460734400
# 2000-01-10  0.910714  0.912946  0.845982  0.872768   0.752894   505064000
# 2000-01-11  0.856585  0.887277  0.808036  0.828125   0.714383   441548800
# 2000-01-12  0.848214  0.852679  0.772321  0.778460   0.671539   976068800
# ...              ...       ...       ...       ...        ...         ...
# 2004-10-21  0.847857  0.859464  0.845714  0.856071   0.738491   724505600
# 2004-10-22  0.848929  0.851250  0.839643  0.846607   0.730326   483067200
# 2004-10-25  0.842857  0.854286  0.840536  0.849107   0.732483   392644000
# 2004-10-26  0.847321  0.858036  0.838750  0.856607   0.738953   594361600
# 2004-10-27  0.866250  0.903929  0.860179  0.898214   0.774845  1193494400
#
# [1073 rows x 6 columns]

# %%
apple.query('Close>100')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-07-31  102.885002  106.415001  100.824997  106.260002  105.886086
# 2020-08-03  108.199997  111.637497  107.892502  108.937500  108.554153
# 2020-08-04  109.132500  110.790001  108.387497  109.665001  109.279099
# 2020-08-05  109.377502  110.392502  108.897499  110.062500  109.675194
# 2020-08-06  110.404999  114.412498  109.797501  113.902496  113.501678
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2020-07-31  374336800
# 2020-08-03  308151200
# 2020-08-04  173071600
# ...

# %%
apple[(apple.Close>20) & (apple.Volume >50000000)]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-03-13   19.912144   20.292143   19.848215   20.289286   17.502569
# 2012-03-14   20.644644   21.240000   20.549999   21.056429   18.164345
# 2012-03-15   21.414642   21.428928   20.662500   20.912857   18.040499
# 2012-03-16   20.882856   21.042856   20.642857   20.913214   18.040806
# 2012-03-19   21.370358   21.491785   21.037500   21.467857   18.519268
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                 Volume
# Date
# 2012-03-13   690855200
# 2012-03-14  1418844000
# 2012-03-15  1159718000
# ...

# %%
apple.query('Close>20 & Volume >50000000')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-03-13   19.912144   20.292143   19.848215   20.289286   17.502569
# 2012-03-14   20.644644   21.240000   20.549999   21.056429   18.164345
# 2012-03-15   21.414642   21.428928   20.662500   20.912857   18.040499
# 2012-03-16   20.882856   21.042856   20.642857   20.913214   18.040806
# 2012-03-19   21.370358   21.491785   21.037500   21.467857   18.519268
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                 Volume
# Date
# 2012-03-13   690855200
# 2012-03-14  1418844000
# 2012-03-15  1159718000
# ...

# %%
apple.sort_values(by = ['Open'],ascending = False)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-09-02  137.589996  137.979996  127.000000  131.399994  131.173691
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-09-01  132.759995  134.800003  130.529999  134.179993  133.948898
# ...                ...         ...         ...         ...         ...
# 2003-04-25    0.240357    0.242500    0.236250    0.238393    0.205650
# 2003-04-17    0.235714    0.236607    0.227143    0.234286    0.202107
# 2003-04-22    0.235357    0.243214    0.233750    0.241250    0.208114
# 2003-04-21    0.234464    0.235536    0.231786    0.234643    0.202415
# 2003-04-16    0.231964    0.244107    0.230714    0.236429    0.203955
#
#                 Volume
# Date
# 2020-12-29   121047300
# 2020-09-02   200119000
# 2020-12-30    96292700
# ...

# %%
apple.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999909  0.999870  0.999789   0.999126 -0.417934
# High       0.999909  1.000000  0.999830  0.999886   0.999295 -0.416401
# Low        0.999870  0.999830  1.000000  0.999893   0.999171 -0.420295
# Close      0.999789  0.999886  0.999893  1.000000   0.999350 -0.418345
# Adj Close  0.999126  0.999295  0.999171  0.999350   1.000000 -0.414915
# Volume    -0.417934 -0.416401 -0.420295 -0.418345  -0.414915  1.000000

# %%
apple.Open.quantile(0.6)
# Out:
# 16.48271446228026

# %%
import pandas as pd

# %%
apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-63be13414db8> in <module>()
# ----> 1 apple
#
# NameError: name 'apple' is not defined

# %%
# !pip install yfinance

# %%
apple = yf.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-97fd51bda3b0> in <module>()
# ----> 1 apple = yf.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
#       2 apple
#
# NameError: name 'yf' is not defined

# %%
apple = yfinance.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-17d8eb60f14b> in <module>()
# ----> 1 apple = yfinance.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
#
# NameError: name 'yfinance' is not defined

# %%
apple = yf.download('AAPL',start = '2000-01-02', end = '2020-12-31', progress = False)
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    0.936384    1.004464    0.907924    0.999442    0.862170
# 2000-01-04    0.966518    0.987723    0.903460    0.915179    0.789479
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.801033
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.731713
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.766373
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2000-01-03  535796800
# 2000-01-04  512377600
# 2000-01-05  778321600
# ...

# %%
apple.query('Close>100')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-07-31  102.885002  106.415001  100.824997  106.260002  105.886086
# 2020-08-03  108.199997  111.637497  107.892502  108.937500  108.554153
# 2020-08-04  109.132500  110.790001  108.387497  109.665001  109.279099
# 2020-08-05  109.377502  110.392502  108.897499  110.062500  109.675194
# 2020-08-06  110.404999  114.412498  109.797501  113.902496  113.501678
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2020-07-31  374336800
# 2020-08-03  308151200
# 2020-08-04  173071600
# ...

# %%
apple.Open.quantile(0.6)
# Out:
# 16.48271446228026

# %%
apple.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.960007
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.970001
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.690002
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2020-12-23   88223700
# 2020-12-24   54930100
# 2020-12-28  124486200
# 2020-12-29  121047300
# 2020-12-30   96452100

# %%
apple.loc['2000-01-04':'2000-01-07','Open':'Close']
# Out:
#                 Open      High       Low     Close
# Date
# 2000-01-04  0.966518  0.987723  0.903460  0.915179
# 2000-01-05  0.926339  0.987165  0.919643  0.928571
# 2000-01-06  0.947545  0.955357  0.848214  0.848214
# 2000-01-07  0.861607  0.901786  0.852679  0.888393

# %%
apple.tail(2)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.869995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.720001
#
#                Volume
# Date
# 2020-12-29  121047300
# 2020-12-30   96452100

# %%
apple.iloc[0:3,0:4]
# Out:
#                 Open      High       Low     Close
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442
# 2000-01-04  0.966518  0.987723  0.903460  0.915179
# 2000-01-05  0.926339  0.987165  0.919643  0.928571

# %%
apple.iloc[[0,3,6],[0,4]]
# Out:
#                 Open  Adj Close
# Date
# 2000-01-03  0.936384   0.862170
# 2000-01-06  0.947545   0.731713
# 2000-01-11  0.856585   0.714383

# %%
apple.loc['2000-01-06','Open':'Close']
# Out:
# Open     0.947545
# High     0.955357
# Low      0.848214
# Close    0.848214
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
apple.loc[['2000-01-04','2000-01-07'],'Open':'Close']
# Out:
#                 Open      High       Low     Close
# Date
# 2000-01-04  0.966518  0.987723  0.903460  0.915179
# 2000-01-07  0.861607  0.901786  0.852679  0.888393
